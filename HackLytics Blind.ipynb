# %%
import pandas as pd

# %%
data_location = "C:/Users/Raejae/Documents/HackLytics/Hacklytics_Contest/Sandy_Springs_Police_Department - Sandy_Springs_Police_Department.csv"

# %%
data = pd.read_csv(data_location, encoding ='utf-8')

# %%
data.head()
# Out:
#    incident_id  case_number       incident_datetime  \
# 0    952728267   2020000781   01/17/2020 1:30:29 PM
# 1    952728268   2020000768  01/17/2020 12:10:00 PM
# 2    952704703   2020000743   01/17/2020 2:14:38 AM
# 3    952685191   2020000738   01/16/2020 8:30:22 PM
# 4    952704706   2020000729   01/16/2020 4:57:30 PM
#
#              incident_type_primary      incident_description  clearance_type  \
# 0      [SSPD]-LARCENY-FROM VEHICLE    LARCENY - FROM VEHICLE             NaN
# 1  [SSPD]-LARCENY - OTHER OFFENSES  LARCENY - OTHER OFFENSES             NaN
# 2             [SSPD]-DUI - ALCOHOL             DUI - ALCOHOL             NaN
# 3          [SSPD]-DOMESTIC DISPUTE          DOMESTIC DISPUTE             NaN
# 4               [SSPD]-HIT AND RUN               HIT AND RUN             NaN
#
#                     address_1  address_2           city state  ... country  \
# 0  6400 Block POWERS FERRY RD        NaN  SANDY SPRINGS    GA  ...     NaN
# 1  1100 Block PERIMETER CTR W        NaN  SANDY SPRINGS    GA  ...     NaN
# 2    400 Block & WINDSOR PKWY        NaN  SANDY SPRINGS    GA  ...     NaN
# 3      700 Block JEFFERSON DR        NaN  SANDY SPRINGS    GA  ...     NaN
# 4    200 Block & GLENRIDGE DR        NaN  SANDY SPRINGS    GA  ...     NaN
#
#     latitude  longitude              created_at              updated_at  \
# 0  33.903192 -84.435246  01/17/2020 10:37:53 PM  01/17/2020 11:39:10 PM
# 1  33.930031 -84.351129  01/17/2020 10:37:53 PM  01/17/2020 11:39:10 PM
# 2  33.895054 -84.364235   01/17/2020 2:38:41 PM  01/17/2020 11:39:09 PM
# 3  33.967122 -84.357805   01/17/2020 7:38:14 AM  01/17/2020 11:39:08 PM
# 4  33.910091 -84.361732   01/17/2020 2:38:41 PM  01/17/2020 11:39:07 PM
#
#                                        location hour_of_day  day_of_week  \
# 0  POINT (-84.43524649609589 33.90319187235206)          13       Friday
# 1  POINT (-84.35112853386204 33.93003140731569)          12       Friday
# 2   POINT (-84.3642353179997 33.89505417513069)           2       Friday
# 3  POINT (-84.35780518461924 33.96712149775683)          20     Thursday
# 4   POINT (-84.3617320007644 33.91009075598981)          16     Thursday
#
#   parent_incident_type Beats Shapes
# 0   Theft from Vehicle     212688.0
# 1                Theft     212689.0
# 2              Traffic     212685.0
# 3       Family Offense     212686.0
# 4              Traffic     212687.0
#
# [5 rows x 21 columns]
